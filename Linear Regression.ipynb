# %%
## import package
import numpy as np
import matplotlib.pyplot as plt

# %%
## import data
datas = np.genfromtxt('data.csv',delimiter=',')
x = datas[:,0]
y = datas[:,1]

# %%
plt.scatter(x,y)
plt.show()

# %%
## 定义损失函数
